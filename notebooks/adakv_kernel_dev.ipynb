# %%
# !nvidia-smi
# Out:
# Mon Jun 29 16:09:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# private 仓库,clone 要鉴权。用你的 dafanfan token(在 URL 里带上)
TOKEN = ""  # ← 粘你的 dafanfan token(注意:Colab 笔记本别分享出去,免得泄露 token)
# !git clone https://{TOKEN}@github.com/liukefan821/adakv.git
# %cd adakv
# Out:
# Cloning into 'adakv'...
# ...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 36 (delta 0), reused 36 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 20.68 KiB | 6.89 MiB/s, done.
# /content/adakv

# %%
# !pip install -e ".[gpu]" -q
# !python -c "import torch, triton; print('torch', torch.__version__, '| triton', triton.__version__, '| cuda', torch.cuda.is_available())"
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# torch 2.11.0+cu128 | triton 3.6.0 | cuda True

# %%
# !python tests/test_reference.py
# Out:
# PASS  test_adaptive_budget_responds_to_concentration
# PASS  test_converges_to_dense
# PASS  test_forced_blocks_selected
# PASS  test_planted_block_recovered
# PASS  test_shapes_and_gqa
#
# 5 passed

# %%
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !pytest -q tests/test_kernel_parity.py -s
# Out:
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# [Hkv=8 group=4 S=4096 D=128 bs=16] rel_err=2.126e-04  sel_lens(mean=16.0, min=16, max=16)
# .[Hkv=4 group=1 S=8192 D=64 bs=32] rel_err=2.078e-04  sel_lens(mean=16.0, min=16, max=16)
# .
# 2 passed in 12.28s
