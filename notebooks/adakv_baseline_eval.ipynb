# %%
# %cd /content/adakv
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 6000 --needles 6 --trials 8 \
    --budgets 4 6 8 10 \
    --methods full quest est_only adakv_nuc \
    --out results/equal_budget_focused.csv
# Out:
# [Errno 2] No such file or directory: '/content/adakv'
# /content
# python3: can't open file '/content/benchmarks/quality/eval_equal_budget.py': [Errno 2] No such file or directory

# %%
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 6000 --needles 6 --trials 4 --budgets 4 6 8 12 \
    --out results/equal_budget_qwen1p5b.csv
# Out:
# loading Qwen/Qwen2.5-1.5B-Instruct ...
# ...
# config.json: 100% 660/660 [00:00<00:00, 2.66MB/s]
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 27.8MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 72.3MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 120MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 146MB/s]
# model.safetensors: 100% 3.09G/3.09G [00:26<00:00, 117MB/s]
# Loading weights: 100% 338/338 [00:07<00:00, 48.24it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.12MB/s]
# loaded | device cuda:0 | attn adakv
#
# multi-key NIAH | ctx≈6000 tok | 6 needles x 4 trials = 24 queries/cell | sink 1 local 2 c_min 1
#
# method     target  realized  recall     acc
# -------------------------------------------
# full           --        --      --   1.000
# quest           4     4.000   0.310   0.250
# adakv           4     5.635   0.750   0.625
# adakv_nuc       4     4.178   0.499   0.458
# est_only        4     4.000   0.426   0.292
# ...

# %%
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 6000 --needles 6 --trials 8 \
    --budgets 4 6 8 10 \
    --methods full quest est_only adakv_nuc \
    --out results/equal_budget_focused.csv
# Out:
# python3: can't open file '/content/benchmarks/quality/eval_equal_budget.py': [Errno 2] No such file or directory

# %%
# %cd /content
# !rm -rf adakv && git clone https://github.com/liukefan821/adakv.git
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !pip install -U transformers accelerate -q
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 6000 --needles 6 --trials 8 \
    --budgets 4 6 8 10 \
    --methods full quest est_only adakv_nuc \
    --out results/equal_budget_focused.csv
# Out:
# /content
# Cloning into 'adakv'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 102 (delta 37), reused 89 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 62.76 KiB | 4.18 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# loading Qwen/Qwen2.5-1.5B-Instruct ...
# config.json: 100% 660/660 [00:00<00:00, 3.10MB/s]
# ...
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 21.8MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 49.9MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 71.7MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 94.7MB/s]
# ...

# %%
# %cd /content
# !rm -rf adakv && git clone https://github.com/liukefan821/adakv.git
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !pip install -U transformers accelerate -q
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 6000 --needles 6 --trials 8 --needles-per-query 3 \
    --budgets 4 6 8 10 \
    --methods full quest est_only adakv_nuc \
    --out results/equal_budget_multineedle.csv
# Out:
# /content
# Cloning into 'adakv'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 107 (delta 40), reused 93 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 64.44 KiB | 2.80 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# loading Qwen/Qwen2.5-1.5B-Instruct ...
# ...
# Loading weights: 100% 338/338 [00:08<00:00, 41.97it/s]
# loaded | device cuda:0 | attn adakv
#
# multi-key NIAH | ctx≈6000 tok | 6 needles x 8 trials | 3 needle(s)/query = 48 code-retrievals/cell | sink 1 local 2 c_min 1
#
# method     target  realized  recall     acc
# ...

# %%
# %cd /content
# !rm -rf adakv && git clone https://github.com/liukefan821/adakv.git
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !pip install -U transformers accelerate -q
# !python benchmarks/quality/eval_equal_budget.py \
    --model Qwen/Qwen2.5-1.5B-Instruct \
    --ctx 16000 --needles 8 --trials 6 --needles-per-query 3 \
    --budgets 4 6 8 12 \
    --methods full quest est_only adakv_nuc \
    --out results/equal_budget_16k.csv
# Out:
# /content
# Cloning into 'adakv'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 107 (delta 40), reused 93 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 64.44 KiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# loading Qwen/Qwen2.5-1.5B-Instruct ...
# ...
# Loading weights: 100% 338/338 [00:03<00:00, 105.33it/s]
# loaded | device cuda:0 | attn adakv
#
# multi-key NIAH | ctx≈16000 tok | 8 needles x 6 trials | 3 needle(s)/query = 36 code-retrievals/cell | sink 1 local 2 c_min 1
#
# method     target  realized  recall     acc
# ...

# %%
# %cd /content
# !rm -rf adakv && git clone https://github.com/liukefan821/adakv.git
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !python benchmarks/efficiency/bench_decode_latency.py \
    --ctx 4096 8192 16384 32768 --budget-blocks 64
# Out:
# /content
# Cloning into 'adakv'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 114 (delta 43), reused 98 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 70.44 KiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# device cuda | dtype torch.float16 | attn backend triton
# Hq 12 Hkv 2 D 128 | block_size 16 | budget 64 blocks/head (= 1024 tokens) | sink 1 local 2
#
#    ctx method       ms/tok    tok/s  vs_dense  blk/hd  KV_MB/tok  summ_MB
# -------------------------------------------------------------------------
# ...

# %%
# %cd /content
# !rm -rf adakv && git clone https://github.com/liukefan821/adakv.git
# %cd /content/adakv
# !pip install -e ".[gpu]" -q
# !python benchmarks/efficiency/bench_decode_latency.py \
    --ctx 4096 8192 16384 32768 65536 131072 --budget-blocks 64
# Out:
# /content
# Cloning into 'adakv'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 119 (delta 45), reused 101 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 71.33 KiB | 1.08 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/adakv
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for adakv (pyproject.toml) ... done
# device cuda | dtype torch.float16 | attn backend triton
# Hq 12 Hkv 2 D 128 | block_size 16 | budget 64 blocks/head (= 1024 tokens) | sink 1 local 2
#
#    ctx method       ms/tok    tok/s  vs_dense  blk/hd  KV_MB/tok  summ_MB
# -------------------------------------------------------------------------
# ...
